# %% [markdown]
# # Library Imports

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
import cv2

# %% [markdown]
# # Dataset and Preprocessing

# %%
DATASET_LOCATION = "animal_dataset/animal_dataset/"

# %%
import os
# Filter to get only directories (which represent class labels)
all_items = os.listdir(DATASET_LOCATION)
LABELS = [item for item in all_items if os.path.isdir(os.path.join(DATASET_LOCATION, item))]
LABELS.sort() # Optional: to ensure consistent ordering

# %%
from PIL import Image
import os
import numpy as np

def load_images(location):
  images = []

  # Use the globally defined LABELS list which should now contain only class directories
  for class_label_index, folder_name in enumerate(LABELS):
    folder_path = os.path.join(location, folder_name)

    # Ensure folder_path is actually a directory, though LABELS should ensure this
    if not os.path.isdir(folder_path):
        continue

    for image_file_name in os.listdir(folder_path):
      img_path = os.path.join(folder_path, image_file_name)

      # Check if it's a file before attempting to open it as an image
      if os.path.isfile(img_path):
        try:
          img = Image.open(img_path)
          img_arr = np.array(img)
          images.append((img_arr, class_label_index))
        except Exception as e:
          print(f"Warning: Could not open {img_path} as an image. Error: {e}")
  return images

# %%
# Load images
images = load_images(DATASET_LOCATION) # image array, class label

# %%
print(LABELS[images[250][1]])
images[250][0]
# Out:
# panda
# array([[[  4,   0,   5],
#         [  5,   0,   3],
#         [  6,   2,   1],
#         ...,
#         [ 54,  61,   7],
#         [148, 156,  97],
#         [133, 139,  79]],
#
#        [[  5,  14,   9],
#         [  1,   8,   1],
#         [  1,   8,   0],
#         ...,
#         [ 70,  70,  20],
#         [123, 128,  70],
#         [146, 156,  93]],
#
#        [[  8,  33,  14],
#         [  5,  28,  12],
#         [  1,  22,   7],
#         ...,
#         [125, 114,  68],
#         [110, 109,  52],
#         [144, 153,  88]],
#
#        ...,
#
#        [[224, 250, 161],
#         [209, 235, 138],
#         [117, 139,  39],
#         ...,
#         [  3,   3,   3],
#         [  3,   3,   3],
#         [  3,   3,   3]],
#
#        [[194, 219, 125],
#         [188, 210, 112],
#         [218, 233, 138],
#         ...,
#         [  4,   4,   4],
#         [  4,   4,   4],
#         [  4,   4,   4]],
#
#        [[179, 201, 100],
#         [226, 244, 144],
#         [243, 255, 162],
#         ...,
#         [  4,   4,   4],
#         [  4,   4,   4],
#         [  4,   4,   4]]], shape=(375, 500, 3), dtype=uint8)

# %%
X = np.array([image[0] for image in images], dtype=object)
y = np.array([image[1] for image in images])
print(len(X), len(y))
# Out:
# 300 300

# %%
# Normalizing images
normalized = False
if not normalized:
  X = X / 255.0
  normalized = True
X[:2]
# Out:
# array([array([[[0.31372549, 0.51372549, 0.63529412],
#                [0.31764706, 0.51764706, 0.63921569],
#                [0.31764706, 0.51764706, 0.63921569],
#                ...,
#                [0.31372549, 0.43921569, 0.5372549 ],
#                [0.3254902 , 0.45098039, 0.54901961],
#                [0.33333333, 0.45882353, 0.55686275]],
#
#               [[0.31372549, 0.51372549, 0.63529412],
#                [0.32156863, 0.52156863, 0.64313725],
#                [0.32156863, 0.52156863, 0.64313725],
#                ...,
#                [0.30588235, 0.43921569, 0.5372549 ],
#                [0.31764706, 0.44313725, 0.54117647],
#                [0.31372549, 0.44705882, 0.54509804]],
#
#               [[0.31764706, 0.51764706, 0.63921569],
#                [0.3254902 , 0.5254902 , 0.64705882],
#                [0.33333333, 0.53333333, 0.65490196],
#                ...,
#                [0.30588235, 0.44705882, 0.54117647],
#                [0.30588235, 0.43921569, 0.5372549 ],
#                [0.29803922, 0.43921569, 0.53333333]],
#
#               ...,
#
#               [[0.12156863, 0.07058824, 0.04705882],
#                [0.10980392, 0.05882353, 0.03529412],
#                [0.10980392, 0.05490196, 0.04313725],
#                ...,
#                [0.23921569, 0.16862745, 0.11372549],
#                [0.2       , 0.12941176, 0.08235294],
#                [0.17254902, 0.10196078, 0.04705882]],
#
#               [[0.12156863, 0.07058824, 0.04705882],
#                [0.10980392, 0.05882353, 0.03529412],
#                [0.11372549, 0.05882353, 0.04705882],
#                ...,
#                [0.23137255, 0.16470588, 0.10196078],
#                [0.20784314, 0.1372549 , 0.08235294],
#                [0.2       , 0.13333333, 0.07058824]],
#
#               [[0.12156863, 0.07058824, 0.04705882],
#                [0.11372549, 0.0627451 , 0.03921569],
#                [0.11764706, 0.0627451 , 0.05098039],
#                ...,
#                [0.2       , 0.13333333, 0.07058824],
#                [0.2       , 0.13333333, 0.07058824],
#                [0.20392157, 0.1372549 , 0.0745098 ]]], shape=(374, 500, 3)),
#        array([[[0.55294118, 0.5372549 , 0.49019608],
#                [0.48235294, 0.47058824, 0.44313725],
#                [0.49411765, 0.49803922, 0.50588235],
#                ...,
#                [0.05882353, 0.05490196, 0.03921569],
#                [0.05882353, 0.05490196, 0.03921569],
#                [0.05882353, 0.05490196, 0.03921569]],
#
#               [[0.5254902 , 0.50980392, 0.46666667],
#                [0.50588235, 0.49411765, 0.4745098 ],
#                [0.49803922, 0.50196078, 0.51764706],
#                ...,
#                [0.0745098 , 0.07058824, 0.05490196],
#                [0.0745098 , 0.07058824, 0.05490196],
#                [0.0745098 , 0.07058824, 0.05490196]],
#
#               [[0.48235294, 0.47058824, 0.44313725],
#                [0.53333333, 0.52941176, 0.52156863],
#                [0.51372549, 0.51372549, 0.54509804],
#                ...,
#                [0.08235294, 0.07843137, 0.0627451 ],
#                [0.08235294, 0.07843137, 0.0627451 ],
#                [0.08235294, 0.07843137, 0.0627451 ]],
#
#               ...,
#
#               [[0.43137255, 0.41568627, 0.40392157],
#                [0.4745098 , 0.4627451 , 0.44313725],
#                [0.51764706, 0.50588235, 0.47843137],
#                ...,
#                [0.31372549, 0.32156863, 0.31764706],
#                [0.3372549 , 0.35294118, 0.35686275],
#                [0.35686275, 0.37254902, 0.37647059]],
#
#               [[0.35294118, 0.3372549 , 0.3254902 ],
#                [0.4       , 0.38431373, 0.37254902],
#                [0.45490196, 0.44313725, 0.42352941],
#                ...,
#                [0.28627451, 0.29411765, 0.28235294],
#                [0.31372549, 0.33333333, 0.31764706],
#                [0.3372549 , 0.35294118, 0.34901961]],
#
#               [[0.30980392, 0.29411765, 0.29019608],
#                [0.36470588, 0.34901961, 0.3372549 ],
#                [0.43529412, 0.42352941, 0.40392157],
#                ...,
#                [0.26666667, 0.2745098 , 0.2627451 ],
#                [0.29411765, 0.31372549, 0.29019608],
#                [0.31764706, 0.3372549 , 0.32156863]]], shape=(375, 499, 3))],
#       dtype=object)

# %% [markdown]
# ### Grayscale Conversion

# %%
def grayscale_conversion(img_arr):
  if len(img_arr.shape) == 3:
    r, g, b = img_arr[:, :, 0], img_arr[:, :, 1], img_arr[:, :, 2]
    new_img = r*0.299 + 0.587*g + 0.114*b
    return new_img

  return img_arr

# %%
# convert images to grayscale
for i in range(len(images)):
  X[i] = grayscale_conversion(X[i])

# %%
plt.figure(figsize=(6, 6))
plt.subplot(121)
plt.imshow(images[250][0])
plt.title(f"{LABELS[y[250]]} - before conversion")
plt.subplot(122)
plt.imshow(X[250])
plt.title(f"{LABELS[y[250]]} - after conversion")
plt.show()

# %% [markdown]
# ### Resizing Images

# %%
def image_resize(img_arr, size=32, is_library=False):
  if is_library:
    resized_img = cv2.resize(img_arr, (size, size))
    return resized_img

  h, w = img_arr.shape
  resized_img = np.zeros((size, size))
  row_scale = h / size
  col_scale = w / size

  for i in range(32):
    for j in range(32):
      resized_img[i, j] = img_arr[int(i*row_scale), int(j*col_scale)]

  return resized_img

# %%
# Resize images
for i in range(len(images)):
  X[i] = image_resize(X[i], 32, is_library=True)

# %%
plt.figure(figsize=(6, 6))
plt.subplot(121)
plt.imshow(images[250][0])
plt.title(f"{LABELS[y[250]]} - before resize")
plt.subplot(122)
plt.imshow(X[250])
plt.title(f"{LABELS[y[250]]} - after resize")
plt.show()

# %% [markdown]
# # Model Building and Evaluation

# %%
# L1 distance
def L1_distance(a, b):
    return np.sum(np.abs(a - b))

# L2 distance
def L2_distance(a, b):
    return np.sqrt(np.sum((a - b) ** 2))

# %%
K_values = [1, 3, 5, 7, 9]

# %% [markdown]
# ### KNN Prediction

# %%
def KNN_prediction(X_train, y_train, X_test, k, method="L2"):
  # print(X_train.shape, y_train.shape, X_test.shape)

  distances = []
  for i in range(len(X_train)):
    if method == "L1":
      d = L1_distance(X_test, X_train[i])
    else:
      d = L2_distance(X_test, X_train[i])
    distances.append((d, y_train[i]))

  distances.sort()
  top_k = distances[:k]

  labels = [label for label in top_k]
  predicted_label = max(set(labels), key=labels.count)

  return predicted_label

# %% [markdown]
# ### Cross Validation

# %%
def cross_validation(X, y, K_values, method="L2"):
  print(X.shape, y.shape)
  fold_size = len(X) // 5
  accuracies = []
  preds = {k: [] for k in K_values}

  for k in K_values:
    fold_acc = []
    for fold in range(5):
      start = fold * fold_size
      end = (fold + 1) * fold_size
      # print(start, end)

      X_test = X[start:end]
      y_test = y[start:end]

      if fold == 0:
        X_train = X[end:]
        y_train = y[end:]
      else:
        X_train = np.concatenate([X[:start], X[end:]], axis=0)
        y_train = np.concatenate([y[:start], y[end:]], axis=0)

      correct = 0
      for i in range(len(X_test)):
        _, predicted_label = KNN_prediction(X_train, y_train, X_test[i], k, method)
        preds[k].append(predicted_label)

        # print(f"Predicted: {predicted_label}, Actual: {y_test[i]}")
        if predicted_label == y_test[i]:
          correct += 1

      fold_acc.append(correct / len(X_test))

    accuracies.append(np.mean(fold_acc))

  return accuracies, preds

# %%
def show_image(img_arr, label=None):
  plt.figure(figsize=(2, 2))
  plt.imshow(img_arr)
  if label is not None:
    plt.title(f"{LABELS[label]}")
  plt.show()

# %%
n = len(X)
n_train = int(0.8 * n)

n_train
# Out:
# 240

# %% [markdown]
# ### shuffle dataset

# %%
indices = np.arange(n)
np.random.shuffle(indices)
X_shuffled = X[indices]
y_shuffled = y[indices]

# %%
X_train = X_shuffled[:n_train]
y_train = y_shuffled[:n_train]

X_test = X_shuffled[n_train:]
y_test = y_shuffled[n_train:]

len(X_train), len(y_train), len(X_test), len(y_test)
# Out:
# (240, 240, 60, 60)

# %%
freq = {}
for i in range(len(y_train)):
  if y_train[i] in freq:
    freq[y_train[i]] += 1
  else:
    freq[y_train[i]] = 1

freq
# Out:
# {np.int64(0): 82, np.int64(1): 84, np.int64(2): 74}

# %%
pred = KNN_prediction(X_train, y_train, X_test[19], k=3)
pred[1]
# Out:
# np.int64(0)

# %%
# Actual Label
show_image(X_shuffled[n_train+19], pred[1])

# %%
# Predicated Label
show_image(X_test[19], y_test[19])

# %% [markdown]
# # Results and Analysis

# %%
K_values = [1, 3, 5, 7, 9]
L1_accuracies, L1_preds = cross_validation(X_train, y_train, K_values, method="L1")
L2_accuracies, L2_preds = cross_validation(X_train, y_train, K_values, method="L2")
# Out:
# (240,) (240,)
# (240,) (240,)

# %%
L1_accuracies
# Out:
# [np.float64(0.4208333333333334),
#  np.float64(0.4208333333333333),
#  np.float64(0.4291666666666666),
#  np.float64(0.4416666666666667),
#  np.float64(0.4416666666666667)]

# %%
L1_preds.keys()
# Out:
# dict_keys([1, 3, 5, 7, 9])

# %%
plt.figure(figsize=(10, 6))
plt.plot(K_values, L1_accuracies, label="Manhattan (L1)", marker='o')
plt.plot(K_values, L2_accuracies, label="Euclidean (L2)", marker='s')
plt.xlabel("K value")
plt.ylabel("Accuracy")
plt.title("5-Fold Cross Validation Results")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
print(L1_preds.keys())
print(np.array(L1_preds[3]).shape)
np.array(y).shape
# Out:
# dict_keys([1, 3, 5, 7, 9])
# (240,)
# (300,)

# %% [markdown]
# # Discussion

# %% [markdown]
# The comparison between L1 (Manhattan) and L2 (Euclidean) distances showed the following results that we find from the graph of Accuracy VS K value:
# - For K = 1, both L1 and L2 distances showed similar performance.
#
# - For K = 3, 7, and 9, the L2 distance consistently achieved higher accuracy than L1.
#
# - For K = 5, the L1 distance performed slightly better than L2.
#
# L2 distance demonstrated more stable/consistent accuracy trends across the tested K values, whereas L1 showed some fluctuations.
#
# Using normalized input features improved accuracy for both L1 and L2 distance metrics.
#
# Trying additional K values may produce different performance patterns and could further support model tuning.

# %% [markdown]
# # Top 5 Predictions

# %% [markdown]
# L1 (Manhattan Distance)

# %%
for idx, k in enumerate(K_values):
  plt.figure(figsize=(10,10))
  for i in range(5):
    plt.subplot(5, 5, i+1)
    plt.imshow(X_shuffled[i])
    plt.title(f"{LABELS[L1_preds[k][i]]} | {LABELS[y_shuffled[i]]}")
  plt.suptitle(f"K = {k} | Accuracy: {L1_accuracies[idx]:.2f}", fontsize=14)
  plt.tight_layout()
plt.show()

# %% [markdown]
# L2 (Euclidean Distance)

# %%
for idx, k in enumerate(K_values):
  plt.figure(figsize=(10,10))
  for i in range(5):
    plt.subplot(5, 5, i+1)
    plt.imshow(X_shuffled[i])
    plt.title(f"{LABELS[L2_preds[k][i]]} | {LABELS[y_shuffled[i]]}")
  plt.suptitle(f"K = {k} | Accuracy: {L2_accuracies[idx]:.2f}", fontsize=14)
  plt.tight_layout()
  plt.show()

# %%
L1_accuracies
# Out:
# [np.float64(0.375),
#  np.float64(0.3125),
#  np.float64(0.3791666666666667),
#  np.float64(0.39583333333333337),
#  np.float64(0.38333333333333336)]

# %%
L2_accuracies
# Out:
# [np.float64(0.3625),
#  np.float64(0.375),
#  np.float64(0.35000000000000003),
#  np.float64(0.37916666666666665),
#  np.float64(0.36666666666666664)]
